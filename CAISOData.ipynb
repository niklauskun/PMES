# %%
import gridstatusio
import plotly.graph_objects as go
import pandas as pd

gridstatusio.__version__
# Out:
# '0.6.3'

# %%
# make sure to set up API Key in environment variable
# or pass it in as a string
client = gridstatusio.GridStatusClient(api_key='adf9b8bc3137421a9c57b61bf737a055')

# %%
client.list_datasets(filter_term="CAISO")
# Out:
# +-------------------------+----------------------------------------------------+
# |           Key           |                       Value                        |
# +-------------------------+----------------------------------------------------+
# |          Name           |                  CAISO As Prices                   |
# |           ID            |                  caiso_as_prices                   |
# |       Description       |  Ancillary Services Prices as reported by CAISO.   |
# | Earliest available time |             2010-01-01T08:00:00+00:00              |
# |  Latest available time  |             2024-08-01T06:00:00+00:00              |
# |    Available columns    |         No available columns information.          |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_as_prices |
# +-------------------------+----------------------------------------------------+
#
#
# +-------------------------+-------------------------------------------------------------------+
# |           Key           |                               Value                               |
# +-------------------------+-------------------------------------------------------------------+
# |          Name           |                     CAISO As Procurement Dam                      |
# |           ID            |                     caiso_as_procurement_dam                      |
# |       Description       |          Ancillary services procurement data from CAISO.          |
# |                         |        Includes total MW procured and costs.  Corresponds         |
# |                         | to CAISO AS_RESULTS dataset on OASIS. See caiso_as_prices dataset |
# |                         |          for per MW prices that result from market run.           |
# | Earliest available time |                     2010-01-01T08:00:00+00:00                     |
# |  Latest available time  |                     2024-08-01T06:00:00+00:00                     |
# |    Available columns    |                 No available columns information.                 |
# |        More Info        |    https://www.gridstatus.io/datasets/caiso_as_procurement_dam    |
# +-------------------------+-------------------------------------------------------------------+
#
#
# +-------------------------+--------------------------------------------------------------------------------------------------+
# |           Key           |                                              Value                                               |
# +-------------------------+--------------------------------------------------------------------------------------------------+
# |          Name           |                         CAISO Curtailed Non Operational Generator Report                         |
# |           ID            |                         caiso_curtailed_non_operational_generator_report                         |
# |       Description       |            Prior Day Curtailed Non-Operational Generator Report as reported by CAISO.            |
# |                         |                                                                                                  |
# |                         | Source: https://www.caiso.com/market-operations/outages/curtailed-and-non-operational-generators |
# |                         |                             Glossary: https://www.caiso.com/glossary                             |
# | Earliest available time |                                    2021-06-18T07:00:00+00:00                                     |
# |  Latest available time  |                                    2024-07-31T07:00:00+00:00                                     |
# |    Available columns    |                                No available columns information.                                 |
# |        More Info        |       https://www.gridstatus.io/datasets/caiso_curtailed_non_operational_generator_report        |
# +-------------------------+--------------------------------------------------------------------------------------------------+
#
#
# +-------------------------+-----------------------------------------------------------------------------+
# |           Key           |                                    Value                                    |
# +-------------------------+-----------------------------------------------------------------------------+
# |          Name           |                              CAISO Curtailment                              |
# |           ID            |                              caiso_curtailment                              |
# |       Description       |                Daily Curtailment data as reported by CAISO.                 |
# |                         |                                                                             |
# |                         | Source: https://www.caiso.com/about/our-business/managing-the-evolving-grid |
# | Earliest available time |                          2017-01-01T12:00:00+00:00                          |
# |  Latest available time  |                          2024-07-29T02:00:00+00:00                          |
# |    Available columns    |                      No available columns information.                      |
# |        More Info        |            https://www.gridstatus.io/datasets/caiso_curtailment             |
# +-------------------------+-----------------------------------------------------------------------------+
#
#
# +-------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |           Key           |                                                                             Value                                                                             |
# +-------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |          Name           |                                                              CAISO Curtailment Aggregated Hourly                                                              |
# |           ID            |                                                              caiso_curtailment_aggregated_hourly                                                              |
# |       Description       | CAISO curtailment aggregated by wind and solar on an hourly basis. For more granular data, on curtailment type and reason, see the caiso_curtailment dataset. |
# | Earliest available time |                                                                   2016-06-30T07:00:00+00:00                                                                   |
# |  Latest available time  |                                                                   2023-09-29T01:00:00+00:00                                                                   |
# |    Available columns    |                                                               No available columns information.                                                               |
# |        More Info        |                                            https://www.gridstatus.io/datasets/caiso_curtailment_aggregated_hourly                                             |
# +-------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
#
# +-------------------------+------------------------------------------------------+
# |           Key           |                        Value                         |
# +-------------------------+------------------------------------------------------+
# |          Name           |                    CAISO Fuel Mix                    |
# |           ID            |                    caiso_fuel_mix                    |
# |       Description       | Fuel Mix in 5 minute intervals as reported by CAISO. |
# | Earliest available time |              2018-04-10T07:00:00+00:00               |
# |  Latest available time  |              2024-07-31T15:45:00+00:00               |
# |    Available columns    |          No available columns information.           |
# |        More Info        |  https://www.gridstatus.io/datasets/caiso_fuel_mix   |
# +-------------------------+------------------------------------------------------+
#
#
# +-------------------------+-------------------------------------------------------+
# |           Key           |                         Value                         |
# +-------------------------+-------------------------------------------------------+
# |          Name           |                   CAISO Fuel Prices                   |
# |           ID            |                   caiso_fuel_prices                   |
# |       Description       | Hourly natural fuel prices in $/mmBtu by fuel region. |
# | Earliest available time |               2009-04-01T07:00:00+00:00               |
# |  Latest available time  |               2024-07-31T16:00:00+00:00               |
# |    Available columns    |           No available columns information.           |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_fuel_prices  |
# +-------------------------+-------------------------------------------------------+
#
#
# +-------------------------+---------------------------------------------------------------+
# |           Key           |                             Value                             |
# +-------------------------+---------------------------------------------------------------+
# |          Name           |                  CAISO LMP Day Ahead Hourly                   |
# |           ID            |                  caiso_lmp_day_ahead_hourly                   |
# |       Description       |                     Day Ahead Hourly LMPs                     |
# | Earliest available time |                   2019-03-21T07:00:00+00:00                   |
# |  Latest available time  |                   2024-08-01T06:00:00+00:00                   |
# |    Available columns    |               No available columns information.               |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_lmp_day_ahead_hourly |
# +-------------------------+---------------------------------------------------------------+
#
#
# +-------------------------+---------------------------------------------------------------+
# |           Key           |                             Value                             |
# +-------------------------+---------------------------------------------------------------+
# |          Name           |                  CAISO LMP Real Time 15 Min                   |
# |           ID            |                  caiso_lmp_real_time_15_min                   |
# |       Description       |                   Real Time 15 Minute LMPs                    |
# | Earliest available time |                   2020-01-01T08:00:00+00:00                   |
# |  Latest available time  |                   2024-07-31T16:30:00+00:00                   |
# |    Available columns    |               No available columns information.               |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_lmp_real_time_15_min |
# +-------------------------+---------------------------------------------------------------+
#
#
# +-------------------------+--------------------------------------------------------------+
# |           Key           |                            Value                             |
# +-------------------------+--------------------------------------------------------------+
# |          Name           |                  CAISO LMP Real Time 5 Min                   |
# |           ID            |                  caiso_lmp_real_time_5_min                   |
# |       Description       |                   Real Time 5 Minute LMPs                    |
# | Earliest available time |                  2020-01-01T08:00:00+00:00                   |
# |  Latest available time  |                  2024-07-31T16:05:00+00:00                   |
# |    Available columns    |              No available columns information.               |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_lmp_real_time_5_min |
# +-------------------------+--------------------------------------------------------------+
#
#
# +-------------------------+--------------------------------------------------+
# |           Key           |                      Value                       |
# +-------------------------+--------------------------------------------------+
# |          Name           |                    CAISO Load                    |
# |           ID            |                    caiso_load                    |
# |       Description       | Load in 5 minute intervals as reported by CAISO. |
# | Earliest available time |            2018-04-10T07:00:00+00:00             |
# |  Latest available time  |            2024-07-31T15:45:00+00:00             |
# |    Available columns    |        No available columns information.         |
# |        More Info        |  https://www.gridstatus.io/datasets/caiso_load   |
# +-------------------------+--------------------------------------------------+
#
#
# +-------------------------+--------------------------------------------------------+
# |           Key           |                         Value                          |
# +-------------------------+--------------------------------------------------------+
# |          Name           |                  CAISO Load Forecast                   |
# |           ID            |                  caiso_load_forecast                   |
# |       Description       |     Load Forecast resampled to 5 minute intervals      |
# | Earliest available time |               2009-03-31T16:10:00+00:00                |
# |  Latest available time  |               2024-07-30T16:10:00+00:00                |
# |    Available columns    |           No available columns information.            |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_load_forecast |
# +-------------------------+--------------------------------------------------------+
#
#
# +-------------------------+------------------------------------------------------------+
# |           Key           |                           Value                            |
# +-------------------------+------------------------------------------------------------+
# |          Name           |                  CAISO Load Forecast Dam                   |
# |           ID            |                  caiso_load_forecast_dam                   |
# |       Description       |  Load Forecast in 1 hour intervals as reported by CAISO.   |
# | Earliest available time |                 2009-03-31T16:10:00+00:00                  |
# |  Latest available time  |                 2024-07-30T16:10:00+00:00                  |
# |    Available columns    |             No available columns information.              |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_load_forecast_dam |
# +-------------------------+------------------------------------------------------------+
#
#
# +-------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |           Key           |                                                                                    Value                                                                                     |
# +-------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |          Name           |                                                                       CAISO Outages Aggregated Hourly                                                                        |
# |           ID            |                                                                       caiso_outages_aggregated_hourly                                                                        |
# |       Description       | CAISO Outages Aggregated by forced and planned on an hourly basis. For generator level data including the reason, see the caiso_curtailed_non_operational_generator dataset. |
# | Earliest available time |                                                                          2021-06-17T07:00:00+00:00                                                                           |
# |  Latest available time  |                                                                          2024-07-24T06:00:00+00:00                                                                           |
# |    Available columns    |                                                                      No available columns information.                                                                       |
# |        More Info        |                                                      https://www.gridstatus.io/datasets/caiso_outages_aggregated_hourly                                                      |
# +-------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
#
# +-------------------------+---------------------------------------------------+
# |           Key           |                       Value                       |
# +-------------------------+---------------------------------------------------+
# |          Name           |                   CAISO Records                   |
# |           ID            |                   caiso_records                   |
# |       Description       | Top 10 daily records for various metrics in CAISO |
# | Earliest available time |             2019-09-13T03:40:00+00:00             |
# |  Latest available time  |             2024-07-25T03:10:00+00:00             |
# |    Available columns    |         No available columns information.         |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_records  |
# +-------------------------+---------------------------------------------------+
#
#
# +-------------------------+-------------------------------------------------------------+
# |           Key           |                            Value                            |
# +-------------------------+-------------------------------------------------------------+
# |          Name           |                 CAISO New Records Timeline                  |
# |           ID            |                  caiso_records_timeseries                   |
# |       Description       |              Timeline of new records for CAISO              |
# | Earliest available time |                  2019-07-25T14:50:00+00:00                  |
# |  Latest available time  |                  2024-06-30T15:10:00+00:00                  |
# |    Available columns    |              No available columns information.              |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_records_timeseries |
# +-------------------------+-------------------------------------------------------------+
#
#
# +-------------------------+-------------------------------------------------------------------------+
# |           Key           |                                  Value                                  |
# +-------------------------+-------------------------------------------------------------------------+
# |          Name           |                    CAISO Solar And Wind Forecast Dam                    |
# |           ID            |                    caiso_solar_and_wind_forecast_dam                    |
# |       Description       | Day-ahead solar and wind forecasts by trading hub as reported by CAISO. |
# | Earliest available time |                        2020-12-31T15:00:00+00:00                        |
# |  Latest available time  |                        2024-07-31T14:00:00+00:00                        |
# |    Available columns    |                    No available columns information.                    |
# |        More Info        |  https://www.gridstatus.io/datasets/caiso_solar_and_wind_forecast_dam   |
# +-------------------------+-------------------------------------------------------------------------+
#
#
# +-------------------------+-------------------------------------------------------------+
# |           Key           |                            Value                            |
# +-------------------------+-------------------------------------------------------------+
# |          Name           |              CAISO 5 minute standardized data               |
# |           ID            |                  caiso_standardized_5_min                   |
# |       Description       |        Denormalized 5 minute data for up to 5 years         |
# | Earliest available time |                  2019-07-25T13:35:00+00:00                  |
# |  Latest available time  |                  2024-07-26T07:30:00+00:00                  |
# |    Available columns    |              No available columns information.              |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_standardized_5_min |
# +-------------------------+-------------------------------------------------------------+
#
#
# +-------------------------+--------------------------------------------------------------+
# |           Key           |                            Value                             |
# +-------------------------+--------------------------------------------------------------+
# |          Name           |                CAISO hourly standardized data                |
# |           ID            |                  caiso_standardized_hourly                   |
# |       Description       |          Denormalized hourly data for up to 5 years          |
# | Earliest available time |                  2019-07-25T13:00:00+00:00                   |
# |  Latest available time  |                  2024-07-26T07:00:00+00:00                   |
# |    Available columns    |              No available columns information.               |
# |        More Info        | https://www.gridstatus.io/datasets/caiso_standardized_hourly |
# +-------------------------+--------------------------------------------------------------+
#
#
# +-------------------------+------------------------------------------------------------+
# |           Key           |                           Value                            |
# +-------------------------+------------------------------------------------------------+
# |          Name           |                       CAISO Storage                        |
# |           ID            |                       caiso_storage                        |
# |       Description       | Data on storage and hybrid resources as reported by CAISO. |
# | Earliest available time |                 2023-03-24T07:00:00+00:00                  |
# |  Latest available time  |                 2024-07-31T15:45:00+00:00                  |
# |    Available columns    |             No available columns information.              |
# |        More Info        |      https://www.gridstatus.io/datasets/caiso_storage      |
# +-------------------------+------------------------------------------------------------+

# %%
df = client.get_dataset(
    dataset="caiso_standardized_5_min",
    start="2022-01-01",  # start from beginning of data
    end="2023-12-31",  # end at most recent data
    tz="US/Pacific",  # return time stamps in Pacific time
)
# Out:
# Fetching Page 1...Done in 2.99 seconds.
# Fetching Page 2...Done in 2.72 seconds. Total time: 5.71s. Avg per page: 2.85s
# Fetching Page 3...Done in 2.72 seconds. Total time: 8.43s. Avg per page: 2.81s
# Fetching Page 4...Done in 2.86 seconds. Total time: 11.29s. Avg per page: 2.82s
# Fetching Page 5...Done in 0.86 seconds. Total time: 12.15s. Avg per page: 2.43s
#
# Total number of rows: 209952

# %%
df.to_csv('CAISO_Load.csv')

# %%
df2 = client.get_dataset(
    dataset="caiso_lmp_real_time_5_min",
    start="2022-01-01",  # start from beginning of data
    end="2022-12-31",  # end at most recent data
    filter_column="location",
    filter_value="TH_NP15_GEN-APND",
    tz="US/Pacific",  # return time stamps in Pacific time
)
# Out:
# Fetching Page 1...Done in 30.81 seconds.
# Fetching Page 2...Done in 33.09 seconds. Total time: 63.9s. Avg per page: 31.95s
# Fetching Page 3...Done in 3.34 seconds. Total time: 67.25s. Avg per page: 22.42s
#
# Total number of rows: 104832

# %%
df2.to_csv('CAISO_RTP_2022.csv')

# %%
df3 = client.get_dataset(
    dataset="caiso_lmp_day_ahead_hourly",
    start="2022-01-01",  # start from beginning of data
    end="2022-12-31",  # end at most recent data
    filter_column="location",
    filter_value="TH_NP15_GEN-APND",
    tz="US/Pacific",  # return time stamps in Pacific time
)
# Out:
# Fetching Page 1...Done in 14.56 seconds.
#
# Total number of rows: 8736

# %%
df3.to_csv('CAISO_DAP_2022.csv')
